# %% [markdown]
# # **IMPORTING THE LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # **LOADING THE DATASET**

# %%
df=pd.read_csv("olympics_dataset.csv")
df
# Out:
#       player_id                   Name  Sex            Team  NOC    Year  \
# 0             0              A Dijiang    M           China  CHN  1992.0
# 1             1               A Lamusi    M           China  CHN  2012.0
# 2             2            Gunnar Aaby    M         Denmark  DEN  1920.0
# 3             3            Edgar Aabye    M  Denmark/Sweden  DEN  1900.0
# 4            26  Cornelia (-strannood)    F     Netherlands  NED  1932.0
# ...         ...                    ...  ...             ...  ...     ...
# 9831      11506             Kazm Ayvaz    M          Turkey  TUR  1968.0
# 9832      11507              Ziya Azak    M          Turkey  TUR  1948.0
# 9833      11508              Ziya Azak    M          Turkey  TUR  1948.0
# 9834      11509               Jan Azam    M        Pakistan  PAK  1952.0
# 9835        115                    NaN  NaN             NaN  NaN     NaN
#
#       Season         City          Sport  \
# 0     Summer    Barcelona     Basketball
# 1     Summer       London           Judo
# 2     Summer    Antwerpen       Football
# 3     Summer        Paris     Tug-Of-War
# 4     Summer  Los Angeles      Athletics
# ...      ...          ...            ...
# 9831  Summer  Mexico City      Wrestling
# 9832  Summer       London  Equestrianism
# 9833  Summer       London  Equestrianism
# 9834  Summer     Helsinki       Shooting
# 9835     NaN          NaN            NaN
#
#                                                   Event     Medal
# 0                           Basketball Men's Basketball  No medal
# 1                          Judo Men's Extra-Lightweight  No medal
# 2                               Football Men's Football  No medal
# 3                           Tug-Of-War Men's Tug-Of-War      Gold
# 4                          Athletics Women's 100 metres  No medal
# ...                                                 ...       ...
# 9831           Wrestling Men's Lightweight, Greco-Roman  No medal
# 9832    Equestrianism Men's Three-Day Event, Individual  No medal
# 9833          Equestrianism Men's Three-Day Event, Team  No medal
# 9834  Shooting Men's Small-Bore Rifle, Prone, 50 metres  No medal
# 9835                                                NaN       NaN
#
# [9836 rows x 11 columns]

# %% [markdown]
# # **BASIC DATA INSPECTION**

# %%
df.shape
# Out:
# (9836, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9836 entries, 0 to 9835
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   player_id  9836 non-null   int64
#  1   Name       9835 non-null   object
#  2   Sex        9835 non-null   object
#  3   Team       9835 non-null   object
#  4   NOC        9835 non-null   object
#  5   Year       9835 non-null   float64
#  6   Season     9835 non-null   object
#  7   City       9835 non-null   object
#  8   Sport      9835 non-null   object
#  9   Event      9835 non-null   object
#  10  Medal      9835 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 845.4+ KB

# %%
df.isna().sum()
# Out:
# player_id    0
# Name         1
# Sex          1
# Team         1
# NOC          1
# Year         1
# Season       1
# City         1
# Sport        1
# Event        1
# Medal        1
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       player_id                   Name  Sex            Team  NOC    Year  \
# 0             0              A Dijiang    M           China  CHN  1992.0
# 1             1               A Lamusi    M           China  CHN  2012.0
# 2             2            Gunnar Aaby    M         Denmark  DEN  1920.0
# 3             3            Edgar Aabye    M  Denmark/Sweden  DEN  1900.0
# 4            26  Cornelia (-strannood)    F     Netherlands  NED  1932.0
# ...         ...                    ...  ...             ...  ...     ...
# 9831      11506             Kazm Ayvaz    M          Turkey  TUR  1968.0
# 9832      11507              Ziya Azak    M          Turkey  TUR  1948.0
# 9833      11508              Ziya Azak    M          Turkey  TUR  1948.0
# 9834      11509               Jan Azam    M        Pakistan  PAK  1952.0
# 9835        115                    NaN  NaN             NaN  NaN     NaN
#
#       Season         City          Sport  \
# 0     Summer    Barcelona     Basketball
# 1     Summer       London           Judo
# 2     Summer    Antwerpen       Football
# 3     Summer        Paris     Tug-Of-War
# 4     Summer  Los Angeles      Athletics
# ...      ...          ...            ...
# 9831  Summer  Mexico City      Wrestling
# 9832  Summer       London  Equestrianism
# 9833  Summer       London  Equestrianism
# 9834  Summer     Helsinki       Shooting
# 9835     NaN          NaN            NaN
#
#                                                   Event     Medal
# 0                           Basketball Men's Basketball  No medal
# 1                          Judo Men's Extra-Lightweight  No medal
# 2                               Football Men's Football  No medal
# 3                           Tug-Of-War Men's Tug-Of-War      Gold
# 4                          Athletics Women's 100 metres  No medal
# ...                                                 ...       ...
# 9831           Wrestling Men's Lightweight, Greco-Roman  No medal
# 9832    Equestrianism Men's Three-Day Event, Individual  No medal
# 9833          Equestrianism Men's Three-Day Event, Team  No medal
# 9834  Shooting Men's Small-Bore Rifle, Prone, 50 metres  No medal
# 9835                                                NaN       NaN
#
# [9836 rows x 11 columns]

# %%
df['Season'].unique()
# Out:
# array(['Summer', nan], dtype=object)

# %%
df.drop(['Season'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['player_id', 'Name', 'Sex', 'Team', 'NOC', 'Year', 'City', 'Sport',
#        'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# # **WHICH SPORT WAS THE MOST PLAYED?**

# %%
most_PlayedSport= df['Sport'].value_counts().head(10)
sns.barplot(data=most_PlayedSport,orient='h',palette='rainbow')
plt.xlabel('Number of participants')
plt.ylabel('Sports')
plt.title('Top 10 Most Played Sports')
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_4168\2482023649.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=most_PlayedSport,orient='h',palette='rainbow')
# Text(0.5, 1.0, 'Top 10 Most Played Sports')

# %% [markdown]
# # **WHAT WERE THE DIFFERENCES IN GROWTH TREND OF GYMNASTICS AND SWIMMING?**

# %%
gym=df[df['Sport']=='Gymnastics']
swim=df[df['Sport']=='Swimming']

gym_growth = gym.groupby('Year')['player_id'].nunique()
swim_growth = swim.groupby('Year')['player_id'].nunique()

plt.figure(figsize=(10, 6))
plt.plot(gym_growth.index, gym_growth.values, label='Gymnastics', color='skyblue')
plt.plot(swim_growth.index, swim_growth.values, label='Swimming', color='lightcoral')

plt.xlabel('Year')
plt.ylabel('Number of Athletes')
plt.title('Growth Comparison: Gymnastics vs Swimming')
plt.legend()
plt.show()

# %% [markdown]
# # **WHAT WERE THE TOP 10 TEAMS WITH MOST NUMBER OF PARTICIPANTS?**

# %%
Top_Team= df['Team'].value_counts().head(10)
sns.barplot(data=Top_Team,orient='h',palette='viridis')
plt.xlabel('Number of participants')
plt.ylabel('Teams')
plt.title('Top 10 Teams with most number of participants')
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_4168\1728762122.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=Top_Team,orient='h',palette='viridis')
# Text(0.5, 1.0, 'Top 10 Teams with most number of participants')

# %% [markdown]
# # **ANALYSIS ON BASIS OF SEX**

# %%
gender=df[['Year','Sex','player_id']]
gender.drop_duplicates()
# Out:
#         Year  Sex  player_id
# 0     1992.0    M          0
# 1     2012.0    M          1
# 2     1920.0    M          2
# 3     1900.0    M          3
# 4     1932.0    F         26
# ...      ...  ...        ...
# 9831  1968.0    M      11506
# 9832  1948.0    M      11507
# 9833  1948.0    M      11508
# 9834  1952.0    M      11509
# 9835     NaN  NaN        115
#
# [9836 rows x 3 columns]

# %%
participation=gender.groupby(['Year','Sex']).count().reset_index()
participation
# Out:
#       Year Sex  player_id
# 0   1896.0   M         10
# 1   1900.0   F          2
# 2   1900.0   M         50
# 3   1904.0   M         29
# 4   1906.0   M         73
# 5   1908.0   F          3
# 6   1908.0   M        111
# 7   1912.0   F         11
# 8   1912.0   M        177
# 9   1920.0   F          6
# 10  1920.0   M        164
# 11  1924.0   F          7
# 12  1924.0   M        169
# 13  1928.0   F         12
# 14  1928.0   M        171
# 15  1932.0   F         10
# 16  1932.0   M         60
# 17  1936.0   F         18
# 18  1936.0   M        206
# 19  1948.0   F         23
# 20  1948.0   M        307
# 21  1952.0   F         45
# 22  1952.0   M        254
# 23  1956.0   F         17
# 24  1956.0   M        140
# 25  1960.0   F         54
# 26  1960.0   M        293
# 27  1964.0   F         44
# 28  1964.0   M        279
# 29  1968.0   F         59
# 30  1968.0   M        348
# 31  1972.0   F        110
# 32  1972.0   M        371
# 33  1976.0   F         86
# 34  1976.0   M        290
# 35  1980.0   F         75
# 36  1980.0   M        294
# 37  1984.0   F         80
# 38  1984.0   M        423
# 39  1988.0   F        134
# 40  1988.0   M        484
# 41  1992.0   F        118
# 42  1992.0   M        454
# 43  1996.0   F        163
# 44  1996.0   M        443
# 45  2000.0   F        193
# 46  2000.0   M        418
# 47  2004.0   F        194
# 48  2004.0   M        381
# 49  2008.0   F        231
# 50  2008.0   M        388
# 51  2012.0   F        260
# 52  2012.0   M        363
# 53  2016.0   F        311
# 54  2016.0   M        419

# %% [markdown]
# # **HOW MANY MALES AND FEMALES PARTICIPATED IN OLYMICS EVERY YEAR?**

# %%
male_data = participation[participation['Sex'] == 'M']
plt.plot(male_data['Year'], male_data['player_id'], label='Male', color='skyblue')

female_data = participation[participation['Sex'] == 'F']
plt.plot(female_data['Year'], female_data['player_id'], label='Female', color='coral')

plt.title('Male and Female Participation in the Olympics')
plt.xlabel('Year')
plt.ylabel('Number of Participants')
plt.legend(title='Sex')
plt.show()

print("Number of Gender-wise participants each year\n", participation)
# Out:
# Number of Gender-wise participants each year
#        Year Sex  player_id
# 0   1896.0   M         10
# 1   1900.0   F          2
# 2   1900.0   M         50
# 3   1904.0   M         29
# 4   1906.0   M         73
# 5   1908.0   F          3
# 6   1908.0   M        111
# 7   1912.0   F         11
# 8   1912.0   M        177
# 9   1920.0   F          6
# 10  1920.0   M        164
# 11  1924.0   F          7
# 12  1924.0   M        169
# 13  1928.0   F         12
# 14  1928.0   M        171
# 15  1932.0   F         10
# 16  1932.0   M         60
# 17  1936.0   F         18
# 18  1936.0   M        206
# 19  1948.0   F         23
# 20  1948.0   M        307
# 21  1952.0   F         45
# 22  1952.0   M        254
# 23  1956.0   F         17
# 24  1956.0   M        140
# 25  1960.0   F         54
# 26  1960.0   M        293
# 27  1964.0   F         44
# 28  1964.0   M        279
# 29  1968.0   F         59
# 30  1968.0   M        348
# 31  1972.0   F        110
# 32  1972.0   M        371
# 33  1976.0   F         86
# 34  1976.0   M        290
# 35  1980.0   F         75
# 36  1980.0   M        294
# 37  1984.0   F         80
# 38  1984.0   M        423
# 39  1988.0   F        134
# 40  1988.0   M        484
# 41  1992.0   F        118
# 42  1992.0   M        454
# 43  1996.0   F        163
# 44  1996.0   M        443
# 45  2000.0   F        193
# 46  2000.0   M        418
# 47  2004.0   F        194
# 48  2004.0   M        381
# 49  2008.0   F        231
# 50  2008.0   M        388
# 51  2012.0   F        260
# 52  2012.0   M        363
# 53  2016.0   F        311
# 54  2016.0   M        419

# %% [markdown]
# # **WHAT WERE THE NUMBER OF MEDALS WON BY MALES AND FEMALES IN EACH YEAR?**

# %%
accep_medals=df[df['Medal']!='No medal']
medalCount_gender=accep_medals.groupby(['Year','Sex']).size().reset_index(name='Number of Medals')
medalCount_gender
# Out:
#       Year Sex  Number of Medals
# 0   1896.0   M                 2
# 1   1900.0   F                 1
# 2   1900.0   M                19
# 3   1904.0   M                 8
# 4   1906.0   M                 8
# 5   1908.0   F                 1
# 6   1908.0   M                29
# 7   1912.0   F                 2
# 8   1912.0   M                41
# 9   1920.0   F                 1
# 10  1920.0   M                60
# 11  1924.0   M                20
# 12  1928.0   F                 2
# 13  1928.0   M                29
# 14  1932.0   M                16
# 15  1936.0   M                20
# 16  1948.0   F                 3
# 17  1948.0   M                34
# 18  1952.0   F                 2
# 19  1952.0   M                24
# 20  1956.0   F                 5
# 21  1956.0   M                17
# 22  1960.0   F                 6
# 23  1960.0   M                31
# 24  1964.0   F                12
# 25  1964.0   M                30
# 26  1968.0   F                 1
# 27  1968.0   M                19
# 28  1972.0   F                 5
# 29  1972.0   M                37
# 30  1976.0   F                13
# 31  1976.0   M                32
# 32  1980.0   F                11
# 33  1980.0   M                35
# 34  1984.0   F                18
# 35  1984.0   M                38
# 36  1988.0   F                13
# 37  1988.0   M                36
# 38  1992.0   F                15
# 39  1992.0   M                51
# 40  1996.0   F                25
# 41  1996.0   M                36
# 42  2000.0   F                33
# 43  2000.0   M                41
# 44  2004.0   F                24
# 45  2004.0   M                38
# 46  2008.0   F                26
# 47  2008.0   M                53
# 48  2012.0   F                38
# 49  2012.0   M                45
# 50  2016.0   F                34
# 51  2016.0   M                45

# %%
sns.lineplot(data=medalCount_gender, x='Year', y='Number of Medals', hue='Sex', palette={'M': 'skyblue', 'F': 'salmon'})
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.title('Number of Medals Won by Male and Female Athletes Over the Years')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# # **HOW DO THE TOP 5 TEAMS COMPARE IN TERMS OF MEDAL COUNTS ACROSS DIFFERENT SEX?**

# %%
med_count=accep_medals.groupby(['Team','Sex']).size().unstack(fill_value=0).sort_values(by=['F','M'],ascending=False).head(5)
med_count[['M','F']].plot(kind='bar',stacked=False,color=['Yellow','Purple'])
plt.xlabel('Country')
plt.ylabel('Total number of medals')
plt.title('Comparison of top 5 teams in terms of medal counts across different sex')
plt.show()

# %% [markdown]
# # **WHAT WERE THE NUMBER OF MEDALS EARNED BY TOP 10 TEAMS?**

# %%
Country_Medal=accep_medals.groupby(['NOC','Medal']).size().unstack(fill_value=0).sort_values(by=['Gold','Silver','Bronze'], ascending=False)
top_countries=Country_Medal.head(10)
top_countries
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# USA        27    74      27
# URS        34    39      27
# FRA        15    28      15
# ITA        18    25      19
# GBR        21    22      21
# SWE        24    21      38
# PAK         4    15       9
# DEN         6    15       8
# NOR        11    12      11
# AUS        12    10       8

# %%
top_countries[['Bronze','Silver','Gold']].plot(kind='bar',stacked=True,color=['brown','silver','gold'])
plt.xlabel('Country')
plt.ylabel('Total number of medals')
plt.title('Different medals by top 10 performing countries')
plt.show()

# %% [markdown]
# # **WHO WERE TO 10 PLAYERS WITH MOST NUMBER OF MEDALS?**

# %%
top_PlayersCount=accep_medals.groupby('Name')['Medal'].size().reset_index(name='Medal_Count')
top_Players=top_PlayersCount.sort_values('Medal_Count', ascending=False).head(10)
top_Players
# Out:
#                      Name  Medal_Count
# 616     Nikolay Andrianov           15
# 672      Polina Astakhova           10
# 600         Nathan Adrian            8
# 20       Agneta Andersson            7
# 750        Simona (-tabr)            7
# 655          Paul Anspach            5
# 270  Evelyn (-washington)            5
# 179       Charles Ainslie            5
# 822     Vladimir Artyomov            5
# 217        Denis Ablyazin            5

# %%
sns.barplot(top_Players,x='Name',y='Medal_Count',palette='pastel')
plt.xticks(rotation=90)
plt.xlabel('Name of Player')
plt.ylabel('Total number of medals')
plt.title('Number of medals by top 10 acheivers')
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_4168\1518206676.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(top_Players,x='Name',y='Medal_Count',palette='pastel')
# Text(0.5, 1.0, 'Number of medals by top 10 acheivers')
